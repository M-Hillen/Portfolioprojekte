# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/Bird_strikes.csv')
df.head()
# Out:
#    RecordID AircraftType                  AirportName   AltitudeBin  \
# 0    202152     Airplane                 LAGUARDIA NY  (1000, 2000]
# 1    208159     Airplane  DALLAS/FORT WORTH INTL ARPT       (-1, 0]
# 2    207601     Airplane            LAKEFRONT AIRPORT      (30, 50]
# 3    215953     Airplane          SEATTLE-TACOMA INTL      (30, 50]
# 4    219878     Airplane                 NORFOLK INTL      (30, 50]
#
#       MakeModel NumberStruck  NumberStruckActual                 Effect  \
# 0     B-737-400     Over 100                 859       Engine Shut Down
# 1         MD-80     Over 100                 424                    NaN
# 2         C-500     Over 100                 261                    NaN
# 3     B-737-400     Over 100                 806  Precautionary Landing
# 4  CL-RJ100/200     Over 100                 942                    NaN
#
#       FlightDate         Damage  ... RemainsSentToSmithsonian  \
# ...

# %%
df.describe()
df.dtypes
# Out:
# RecordID                     int64
# AircraftType                object
# AirportName                 object
# AltitudeBin                 object
# MakeModel                   object
# NumberStruck                object
# NumberStruckActual           int64
# Effect                      object
# FlightDate                  object
# Damage                      object
# Engines                     object
# Operator                    object
# OriginState                 object
# FlightPhase                 object
# ConditionsPrecipitation     object
# RemainsCollected?             bool
# RemainsSentToSmithsonian      bool
# Remarks                     object
# WildlifeSize                object
# ConditionsSky               object
# WildlifeSpecies             object
# PilotWarned                 object
# Cost                        object
# Altitude                     int64
# PeopleInjured                int64
# IsAircraftLarge?            object
# dtype: object
